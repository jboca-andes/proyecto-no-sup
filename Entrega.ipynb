# %% [markdown]
# ## Importación de librerías

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.linalg import svd

import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_excel('datos/Premier League 2011-12 Match by Match.xls')
df.head()
# Out:
#          Date  Player ID Player Surname Player Forename       Team  Team Id  \
# 0  2012-04-28      28566     Abou Diaby       Vassiriki    Arsenal        3
# 1  2011-11-26      28566     Abou Diaby       Vassiriki    Arsenal        3
# 2  2012-03-03      28566     Abou Diaby       Vassiriki    Arsenal        3
# 3  2012-04-21      28566     Abou Diaby       Vassiriki    Arsenal        3
# 4  2012-01-03      20208           Adam         Charlie  Liverpool       14
#
#         Opposition  Opposition id Venue  Position Id  ...  Pass Left  \
# 0       Stoke City            110  Away            4  ...          2
# 1           Fulham             54  Home            4  ...          5
# 2        Liverpool             14  Away            4  ...          5
# 3          Chelsea              8  Home            4  ...          6
# 4  Manchester City             43  Away            4  ...         13
#
#    Pass Right  Unsuccessful Ball Touch  Successful Ball Touch  \
# 0           4                        0                      0
# 1           7                        0                      0
# 2           3                        2                      0
# 3           9                        0                      0
# 4          12                        0                      4
#
#    Take-Ons Overrun  CompId  SeasId  Touches open play final third  \
# 0                 0       8    2011                              2
# 1                 0       8    2011                             11
# 2                 0       8    2011                              4
# 3                 0       8    2011                              8
# 4                 0       8    2011                             16
#
#    Touches open play opp box  Touches open play opp six yards
# 0                          1                                0
# 1                          1                                0
# 2                          0                                0
# 3                          1                                0
# 4                          3                                0
#
# [5 rows x 210 columns]

# %% [markdown]
# ## Segmentación del dataframe por posición:
#
# En la tabla de datos se pueden observar 4 tipos de posiciones diferentes (bajo el nombre 'Position Id') las cuales son: arquero (1), defensa (2), mediocampista (4) y delantero (6). Es claro que jugadores en diferentes posiciones no deben ser comparados. Adicionalmente, depende de cada posición algunas variables pierden relevancia y variabilidad (ejemplo, un delantero no puede atajar un penalti 'Penalties Saved').
#
# ### Arqueros:
#
# #### Disminución de dimensiones:

# %%
df_arquero = df[df['Position Id'] == 1]
print("La posición de arquero cuenta con:", df_arquero.shape[0], "Registros diferentes.",
     "\nAdicionalmente, existen", len(df_arquero["Player ID"].unique()), "arqueros diferentes.")
df_arquero.head()
# Out:
# La posición de arquero cuenta con: 766 Registros diferentes.
# Adicionalmente, existen 40 arqueros diferentes.
#            Date  Player ID Player Surname Player Forename            Team  \
# 200  2011-10-01      28491       Al-Habsi             Ali  Wigan Athletic
# 201  2012-04-16      28491       Al-Habsi             Ali  Wigan Athletic
# 202  2011-11-06      28491       Al-Habsi             Ali  Wigan Athletic
# 203  2011-10-29      28491       Al-Habsi             Ali  Wigan Athletic
# 204  2011-11-26      28491       Al-Habsi             Ali  Wigan Athletic
#
#      Team Id               Opposition  Opposition id Venue  Position Id  ...  \
# 200      111              Aston Villa              7  Away            1  ...
# 201      111                  Arsenal              3  Away            1  ...
# 202      111  Wolverhampton Wanderers             39  Away            1  ...
# 203      111                   Fulham             54  Home            1  ...
# 204      111               Sunderland             56  Away            1  ...
#
#      Pass Left  Pass Right  Unsuccessful Ball Touch  Successful Ball Touch  \
# 200          4           1                        0                      0
# 201          7           2                        0                      0
# 202          4           1                        0                      0
# 203          3           2                        0                      0
# 204          5           1                        0                      0
#
#      Take-Ons Overrun  CompId  SeasId  Touches open play final third  \
# 200                 0       8    2011                              0
# 201                 0       8    2011                              0
# 202                 0       8    2011                              0
# 203                 0       8    2011                              0
# 204                 0       8    2011                              0
#
#      Touches open play opp box  Touches open play opp six yards
# 200                          0                                0
# 201                          0                                0
# 202                          0                                0
# 203                          0                                0
# 204                          0                                0
#
# [5 rows x 210 columns]

# %% [markdown]
# Al ser tantas variables, vamos a eliminar todas aquellas que tenga variabilidad igual a cero (probablemente los arqueros no metan goles, entre otras) y las variables que no sean numericas, es todos los casos podemos ver que está un identificador numérico equivalente al dato en texto.

# %%
col_eliminar = []
for col in df_arquero.columns:
    if not df_arquero[col].mad()>0:
        col_eliminar.append(col)

df_arquero.drop(col_eliminar, axis = 1, inplace = True)
print("Se han eliminado las columnas:", col_eliminar, 
      "\n reteniendo únicamente", df_arquero.shape[1], "columnas.")
# Out:
# Se han eliminado las columnas: ['Date', 'Player Surname', 'Player Forename', 'Team', 'Opposition', 'Venue', 'Position Id', 'Appearances', 'Winning Goal', 'Shots Off Target inc woodwork', 'Blocked Shots', 'Penalties Taken', 'Penalty Goals', 'Penalties Saved', 'Penalties Off Target', 'Penalties Not Scored', 'Direct Free-kick Goals', 'Direct Free-kick On Target', 'Direct Free-kick Off Target', 'Blocked Direct Free-kick', 'Goals from Inside Box', 'Shots On from Inside Box', 'Shots Off from Inside Box', 'Blocked Shots from Inside Box', 'Shots Off Target Outside Box', 'Blocked Shots Outside Box', 'Headed Goals', 'Headed Shots On Target', 'Headed Shots Off Target', 'Headed Blocked Shots', 'Left Foot Goals', 'Left Foot Shots On Target', 'Left Foot Shots Off Target', 'Left Foot Blocked Shots', 'Right Foot Shots Off Target', 'Right Foot Blocked Shots', 'Other Goals', 'Other Shots On Target', 'Other Shots Off Target', 'Other Blocked Shots', 'Shots Cleared off Line', 'Shots Cleared off Line Inside Area', 'Shots Cleared off Line Outside Area', 'Goals from Corners', 'Goals from Throws', 'Goals from Direct Free Kick', 'Goals from Set Play', 'Goals from penalties', 'Attempts from Corners on target', 'Attempts from Throws on target', 'Attempts from Direct Free Kick on target', 'Attempts from Set Play on target', 'Attempts from Penalties on target', 'Attempts Open Play off target', 'Attempts from Corners off target', 'Attempts from Throws off target', 'Attempts from Direct Free Kick off target', 'Attempts from Set Play off target', 'Attempts from Penalties off target', 'Goals as a substitute', 'Assists', 'Successful Flick-Ons', 'Unsuccessful Flick-Ons', 'Successful Crosses Corners', 'Corners Taken incl short corners', 'Successful Corners into Box', 'Unsuccessful Corners into Box', 'Short Corners', 'Throw Ins to Opposition Player', 'Successful Crosses Corners Left', 'Successful Crosses Left', 'Successful Corners Left', 'Unsuccessful Corners Left', 'Successful Crosses Corners Right', 'Unsuccessful Crosses Corners Right', 'Successful Crosses Right', 'Unsuccessful Crosses Right', 'Successful Corners Right', 'Unsuccessful Corners Right', 'Through Ball', 'Successful Crosses Corners in the air', 'Successful crosses in the air', 'Successful open play crosses', 'Goal Assist Corner', 'Goal Assist Free Kick', 'Goal Assist Throw In', 'Goal Assist Goal Kick', 'Goal Assist Set Piece', 'Key Corner', 'Key Throw In', 'Clearances Off the Line', 'Blocks', 'Offsides', 'Team Clean sheet', 'Turnovers', 'Big Chances', 'CompId', 'SeasId']
#  reteniendo únicamente 112 columnas.
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Por otro lado, se mantienen algunos datos que no deberían ser decisivos a la hora de determinar arqueros, por ejemplo los goles.

# %%
df_arquero[df_arquero["Goals"]>0]
# Out:
#       Player ID  Team Id  Opposition id  Time Played  Starts  Substitute On  \
# 4464      15337       11             30           90       1              0
#
#       Substitute Off  Goals  First Goal  Shots On Target inc goals  ...  \
# 4464               0      1           1                          1  ...
#
#       Pass Forward  Pass Backward  Pass Left  Pass Right  \
# 4464            20              0          4           2
#
#       Unsuccessful Ball Touch  Successful Ball Touch  Take-Ons Overrun  \
# 4464                        0                      0                 0
#
#       Touches open play final third  Touches open play opp box  \
# 4464                              0                          0
#
#       Touches open play opp six yards
# 4464                                0
#
# [1 rows x 112 columns]

# %% [markdown]
# Observamos que un arquero hizo gol en un partido (esto repercute en variables como gol, primer gol, tiros etc) por lo tanto vamos a omitir este dato y volver a eliminar columnas.

# %%
col_eliminar = []
for col in df_arquero.columns:
    if not df_arquero.loc[df_arquero["Goals"] == 0, col].mad()>0:
        col_eliminar.append(col)

df_arquero.drop(col_eliminar, axis = 1, inplace = True)
print("Se han eliminado las columnas:", col_eliminar, 
      "\n reteniendo únicamente", df_arquero.shape[1], "columnas.")
# Out:
# Se han eliminado las columnas: ['Goals', 'First Goal', 'Shots On Target inc goals', 'Goals from Outside Box', 'Shots On Target Outside Box', 'Right Foot Goals', 'Right Foot Shots On Target', 'Attempts Open Play on target']
#  reteniendo únicamente 104 columnas.
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Ahora, agregamos los datos de cada jugador. Esto teniendo en cuenta que queremos comparar los jugadores entre si, y no por partido individual.

# %%
df_arquero = df_arquero.groupby(['Player ID']).sum()
df_arquero.head()
# Out:
#            Team Id  Opposition id  Time Played  Starts  Substitute On  \
# Player ID
# 1344           540            676         1620      18              0
# 1801           170           1285         3060      34              0
# 1803           228           1416         3420      38              0
# 1822           224           1169         2828      32              0
# 1827          1620           1189         2700      30              0
#
#            Substitute Off  Goals Open Play  Total Successful Passes All  \
# Player ID
# 1344                    0                0                          384
# 1801                    0                0                          367
# 1803                    0                0                          828
# 1822                    1                0                          493
# 1827                    0                0                          677
#
#            Total Unsuccessful Passes All  Key Passes  ...  Pass Forward  \
# Player ID                                             ...
# 1344                                 349           1  ...           658
# 1801                                 854           4  ...          1156
# 1803                                 416           1  ...           816
# 1822                                 442           0  ...           823
# 1827                                 423           0  ...           868
#
#            Pass Backward  Pass Left  Pass Right  Unsuccessful Ball Touch  \
# Player ID
# 1344                   0         35          40                        0
# 1801                   0         27          38                        0
# 1803                   1        166         261                        1
# 1822                   0         54          58                        0
# 1827                   0        108         124                        1
#
#            Successful Ball Touch  Take-Ons Overrun  \
# Player ID
# 1344                           1                 0
# 1801                           1                 0
# 1803                           7                 0
# 1822                           3                 0
# 1827                           4                 0
#
#            Touches open play final third  Touches open play opp box  \
# Player ID
# 1344                                   0                          0
# 1801                                   1                          0
# 1803                                   0                          0
# 1822                                   0                          0
# 1827                                   0                          0
#
#            Touches open play opp six yards
# Player ID
# 1344                                     0
# 1801                                     0
# 1803                                     0
# 1822                                     0
# 1827                                     0
#
# [5 rows x 103 columns]

# %% [markdown]
# Por último, retiramos todas las variables categotricas o identificativas

# %%
df_arquero.columns
# Out:
# Index(['Team Id', 'Opposition id', 'Time Played', 'Starts', 'Substitute On',
#        'Substitute Off', 'Goals Open Play', 'Total Successful Passes All',
#        'Total Unsuccessful Passes All', 'Key Passes',
#        ...
#        'Pass Forward', 'Pass Backward', 'Pass Left', 'Pass Right',
#        'Unsuccessful Ball Touch', 'Successful Ball Touch', 'Take-Ons Overrun',
#        'Touches open play final third', 'Touches open play opp box',
#        'Touches open play opp six yards'],
#       dtype='object', length=103)

# %%
col_eliminar = ["Team Id", 'Opposition id']
df_arquero.drop(col_eliminar, axis = 1, inplace = True)

# %% [markdown]
# Aunque ya hemos disminuido el número de variables, claramente se debe mantener una correlación muy alta entre distintas variables (ejemplo, total pases es la suma de los pases en cada parte de la cancha).

# %%
corr = df_arquero.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_a8d8d_row0_col0, #T_a8d8d_row0_col1, #T_a8d8d_row1_col0, #T_a8d8d_row1_col1, #T_a8d8d_row2_col2, #T_a8d8d_row3_col3, #T_a8d8d_row4_col4, #T_a8d8d_row5_col5, #T_a8d8d_row6_col6, #T_a8d8d_row6_col9, #T_a8d8d_row7_col7, #T_a8d8d_row8_col8, #T_a8d8d_row9_col6, #T_a8d8d_row9_col9, #T_a8d8d_row9_col13, #T_a8d8d_row9_col23, #T_a8d8d_row10_col10, #T_a8d8d_row10_col14, #T_a8d8d_row10_col20, #T_a8d8d_row11_col11, #T_a8d8d_row12_col12, #T_a8d8d_row13_col9, #T_a8d8d_row13_col13, #T_a8d8d_row13_col23, #T_a8d8d_row14_col10, #T_a8d8d_row14_col14, #T_a8d8d_row14_col20, #T_a8d8d_row15_col15, #T_a8d8d_row16_col16, #T_a8d8d_row17_col17, #T_a8d8d_row18_col18, #T_a8d8d_row19_col19, #T_a8d8d_row20_col10, #T_a8d8d_row20_col14, #T_a8d8d_row20_col20, #T_a8d8d_row21_col21, #T_a8d8d_row22_col22, #T_a8d8d_row23_col9, #
{
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_a8d8d_row0_col6, #T_a8d8d_row0_col16, #T_a8d8d_row1_col6, #T_a8d8d_row5_col17, #T_a8d8d_row5_col42, #T_a8d8d_row5_col94, #T_a8d8d_row6_col55, #T_a8d8d_row6_col86, #T_a8d8d_row6_col90, #T_a8d8d_row8_c

# %% [markdown]
# Todavía el número de variables es demasiado alto para hacer análisis uno a uno, por lo tanto, vamos a utilizar svd para reducir dimensiones, haciendo transformaciones a espacios vectoriales más pequeños, buscando mantener el máximo de variabilidad.

# %%
scaler = StandardScaler()
scaler.fit(df_arquero)
df_arquero_transformada =scaler.transform(df_arquero)

U, S, VT = svd(df_arquero_transformada, full_matrices=False)

idx = range(len(S))
func = [S[0]/((i+1) ** 2) for i in idx ]
plt.plot(idx,func) 
plt.title("Variabilidad explicada")
plt.show()

# %%
var_explained = np.round(S**2/np.sum(S**2), decimals=6)
num_components = 13
sum(var_explained[0:num_components])
# Out:
# 0.9109110000000001

# %% [markdown]
# Podemos observar que al retener unicamente 13 componentes del espacio vectorial transformado, mantenemos más del $90\%$ de la variabilidad o información, lo cual consideramos que es bastante aceptable

# %%
df_arquero_transformada = df_arquero_transformada @ VT[:num_components,:].T

# %% [markdown]
# ### agrupación de datos
#
# Para esto, vamos a utilizar una clustering jerarquico, la principal razón de esta elección, es que no tenemos un número fijo de clusters deseables, sin embargo, queremos que haya bastantes grupos, buscando mantener un equilibrio entre la cantidad de grupos y el tamaño de los mismos.

# %%
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage

dist = pdist(df_arquero_transformada, metric='euclidean')
Z = linkage(dist, method='ward')

distancia_max = 15

fig, ax = plt.subplots(figsize=(12, 8))
d = dendrogram(Z, ax=ax, color_threshold=distancia_max)
ax.set_xlabel('Observaciones', fontsize=14)
ax.set_ylabel('Distancia', fontsize=14)
plt.axhline(y=distancia_max, c='k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w5/brx487w15d58wkrdf9wc_ghm0000gn/T/ipykernel_30409/3388976002.py in <module>
#       8
#       9 fig, ax = plt.subplots(figsize=(12, 8))
# ---> 10 d = dendrogram(Z, ax=ax, color_threshold=distancia_max)
#      11 ax.set_xlabel('Observaciones', fontsize=14)
#      12 ax.set_ylabel('Distancia', fontsize=14)
#
# NameError: name 'dendrogram' is not defined

# %% [markdown]
# Como se puede notar en la gráfica anterior, al delimitar una distacia máxima de 15, mantendríamos 7 grupos. Sin embargo dos grupos solo contienen un elemento. Los arqueros es la posición más dificil de agrupar debido a la cantidad de jugadores que aparecen.

# %%
from scipy.cluster.hierarchy import fcluster
cluster_jerarquico = fcluster(Z, distancia_max, criterion="distance")
print("En el orden inicial, cada registro pertenecería al siguiente cluster:", cluster_jerarquico)
