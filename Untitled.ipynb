# %% [markdown]
# ## Importación de librerías

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.linalg import svd

import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_excel('datos/Premier League 2011-12 Match by Match.xls')
df.head()
# Out:
#          Date  Player ID Player Surname Player Forename       Team  Team Id  \
# 0  2012-04-28      28566     Abou Diaby       Vassiriki    Arsenal        3
# 1  2011-11-26      28566     Abou Diaby       Vassiriki    Arsenal        3
# 2  2012-03-03      28566     Abou Diaby       Vassiriki    Arsenal        3
# 3  2012-04-21      28566     Abou Diaby       Vassiriki    Arsenal        3
# 4  2012-01-03      20208           Adam         Charlie  Liverpool       14
#
#         Opposition  Opposition id Venue  Position Id  ...  Pass Left  \
# 0       Stoke City            110  Away            4  ...          2
# 1           Fulham             54  Home            4  ...          5
# 2        Liverpool             14  Away            4  ...          5
# 3          Chelsea              8  Home            4  ...          6
# 4  Manchester City             43  Away            4  ...         13
#
#    Pass Right  Unsuccessful Ball Touch  Successful Ball Touch  \
# 0           4                        0                      0
# 1           7                        0                      0
# 2           3                        2                      0
# 3           9                        0                      0
# 4          12                        0                      4
#
#    Take-Ons Overrun  CompId  SeasId  Touches open play final third  \
# 0                 0       8    2011                              2
# 1                 0       8    2011                             11
# 2                 0       8    2011                              4
# 3                 0       8    2011                              8
# 4                 0       8    2011                             16
#
#    Touches open play opp box  Touches open play opp six yards
# 0                          1                                0
# 1                          1                                0
# 2                          0                                0
# 3                          1                                0
# 4                          3                                0
#
# [5 rows x 210 columns]

# %% [markdown]
# ## Segmentación del dataframe por posición:
#
# En la tabla de datos se pueden observar 4 tipos de posiciones diferentes (bajo el nombre 'Position Id') las cuales son: arquero (1), defensa (2), mediocampista (4) y delantero (6). Es claro que jugadores en diferentes posiciones no deben ser comparados. Adicionalmente, depende de cada posición algunas variables pierden relevancia y variabilidad (ejemplo, un delantero no puede atajar un penalti 'Penalties Saved').
#
# ### Arqueros:
#
# ####

# %%
df_arquero = df[df['Position Id'] == 1]
print("La posición de arquero cuenta con:", df_arquero.shape[0], "Registros diferentes.",
     "\nAdicionalmente, existen", len(df_arquero["Player ID"].unique()), "arqueros diferentes.")
df_arquero.head()
# Out:
# La posición de arquero cuenta con: 766 Registros diferentes.
# Adicionalmente, existen 40 arqueros diferentes.
#            Date  Player ID Player Surname Player Forename            Team  \
# 200  2011-10-01      28491       Al-Habsi             Ali  Wigan Athletic
# 201  2012-04-16      28491       Al-Habsi             Ali  Wigan Athletic
# 202  2011-11-06      28491       Al-Habsi             Ali  Wigan Athletic
# 203  2011-10-29      28491       Al-Habsi             Ali  Wigan Athletic
# 204  2011-11-26      28491       Al-Habsi             Ali  Wigan Athletic
#
#      Team Id               Opposition  Opposition id Venue  Position Id  ...  \
# 200      111              Aston Villa              7  Away            1  ...
# 201      111                  Arsenal              3  Away            1  ...
# 202      111  Wolverhampton Wanderers             39  Away            1  ...
# 203      111                   Fulham             54  Home            1  ...
# 204      111               Sunderland             56  Away            1  ...
#
#      Pass Left  Pass Right  Unsuccessful Ball Touch  Successful Ball Touch  \
# 200          4           1                        0                      0
# 201          7           2                        0                      0
# 202          4           1                        0                      0
# 203          3           2                        0                      0
# 204          5           1                        0                      0
#
#      Take-Ons Overrun  CompId  SeasId  Touches open play final third  \
# 200                 0       8    2011                              0
# 201                 0       8    2011                              0
# 202                 0       8    2011                              0
# 203                 0       8    2011                              0
# 204                 0       8    2011                              0
#
#      Touches open play opp box  Touches open play opp six yards
# 200                          0                                0
# 201                          0                                0
# 202                          0                                0
# 203                          0                                0
# 204                          0                                0
#
# [5 rows x 210 columns]

# %% [markdown]
# Al ser tantas variables, vamos a eliminar todas aquellas que tenga variabilidad igual a cero (probablemente los arqueros no metan goles, entre otras) y las variables que no sean numericas, es todos los casos podemos ver que está un identificador numérico equivalente al dato en texto.

# %%
col_eliminar = []
for col in df_arquero.columns:
    if not df_arquero[col].mad()>0:
        col_eliminar.append(col)

df_arquero.drop(col_eliminar, axis = 1, inplace = True)
print("Se han eliminado las columnas:", col_eliminar, 
      "\n reteniendo únicamente", df_arquero.shape[1], "columnas.")
# Out:
# Se han eliminado las columnas: ['Date', 'Player Surname', 'Player Forename', 'Team', 'Opposition', 'Venue', 'Position Id', 'Appearances', 'Winning Goal', 'Shots Off Target inc woodwork', 'Blocked Shots', 'Penalties Taken', 'Penalty Goals', 'Penalties Saved', 'Penalties Off Target', 'Penalties Not Scored', 'Direct Free-kick Goals', 'Direct Free-kick On Target', 'Direct Free-kick Off Target', 'Blocked Direct Free-kick', 'Goals from Inside Box', 'Shots On from Inside Box', 'Shots Off from Inside Box', 'Blocked Shots from Inside Box', 'Shots Off Target Outside Box', 'Blocked Shots Outside Box', 'Headed Goals', 'Headed Shots On Target', 'Headed Shots Off Target', 'Headed Blocked Shots', 'Left Foot Goals', 'Left Foot Shots On Target', 'Left Foot Shots Off Target', 'Left Foot Blocked Shots', 'Right Foot Shots Off Target', 'Right Foot Blocked Shots', 'Other Goals', 'Other Shots On Target', 'Other Shots Off Target', 'Other Blocked Shots', 'Shots Cleared off Line', 'Shots Cleared off Line Inside Area', 'Shots Cleared off Line Outside Area', 'Goals from Corners', 'Goals from Throws', 'Goals from Direct Free Kick', 'Goals from Set Play', 'Goals from penalties', 'Attempts from Corners on target', 'Attempts from Throws on target', 'Attempts from Direct Free Kick on target', 'Attempts from Set Play on target', 'Attempts from Penalties on target', 'Attempts Open Play off target', 'Attempts from Corners off target', 'Attempts from Throws off target', 'Attempts from Direct Free Kick off target', 'Attempts from Set Play off target', 'Attempts from Penalties off target', 'Goals as a substitute', 'Assists', 'Successful Flick-Ons', 'Unsuccessful Flick-Ons', 'Successful Crosses Corners', 'Corners Taken incl short corners', 'Successful Corners into Box', 'Unsuccessful Corners into Box', 'Short Corners', 'Throw Ins to Opposition Player', 'Successful Crosses Corners Left', 'Successful Crosses Left', 'Successful Corners Left', 'Unsuccessful Corners Left', 'Successful Crosses Corners Right', 'Unsuccessful Crosses Corners Right', 'Successful Crosses Right', 'Unsuccessful Crosses Right', 'Successful Corners Right', 'Unsuccessful Corners Right', 'Through Ball', 'Successful Crosses Corners in the air', 'Successful crosses in the air', 'Successful open play crosses', 'Goal Assist Corner', 'Goal Assist Free Kick', 'Goal Assist Throw In', 'Goal Assist Goal Kick', 'Goal Assist Set Piece', 'Key Corner', 'Key Throw In', 'Clearances Off the Line', 'Blocks', 'Offsides', 'Team Clean sheet', 'Turnovers', 'Big Chances', 'CompId', 'SeasId']
#  reteniendo únicamente 112 columnas.
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Por otro lado, se mantienen algunos datos que no deberían ser decisivos a la hora de determinar arqueros, por ejemplo los goles.

# %%
df_arquero[df_arquero["Goals"]>0]
# Out:
#       Player ID  Team Id  Opposition id  Time Played  Starts  Substitute On  \
# 4464      15337       11             30           90       1              0
#
#       Substitute Off  Goals  First Goal  Shots On Target inc goals  ...  \
# 4464               0      1           1                          1  ...
#
#       Pass Forward  Pass Backward  Pass Left  Pass Right  \
# 4464            20              0          4           2
#
#       Unsuccessful Ball Touch  Successful Ball Touch  Take-Ons Overrun  \
# 4464                        0                      0                 0
#
#       Touches open play final third  Touches open play opp box  \
# 4464                              0                          0
#
#       Touches open play opp six yards
# 4464                                0
#
# [1 rows x 112 columns]

# %% [markdown]
# Observamos que un arquero hizo gol en un partido (esto repercute en variables como gol, primer gol, tiros etc) por lo tanto vamos a omitir este dato y volver a eliminar columnas.

# %%
col_eliminar = []
for col in df_arquero.columns:
    if not df_arquero.loc[df_arquero["Goals"] == 0, col].mad()>0:
        col_eliminar.append(col)

df_arquero.drop(col_eliminar, axis = 1, inplace = True)
print("Se han eliminado las columnas:", col_eliminar, 
      "\n reteniendo únicamente", df_arquero.shape[1], "columnas.")
# Out:
# Se han eliminado las columnas: ['Goals', 'First Goal', 'Shots On Target inc goals', 'Goals from Outside Box', 'Shots On Target Outside Box', 'Right Foot Goals', 'Right Foot Shots On Target', 'Attempts Open Play on target']
#  reteniendo únicamente 104 columnas.
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Por último, retiramos todas las variables categotricas o identificativas

# %%
df_arquero.columns
# Out:
# Index(['Player ID', 'Team Id', 'Opposition id', 'Time Played', 'Starts',
#        'Substitute On', 'Substitute Off', 'Goals Open Play',
#        'Total Successful Passes All', 'Total Unsuccessful Passes All',
#        ...
#        'Pass Forward', 'Pass Backward', 'Pass Left', 'Pass Right',
#        'Unsuccessful Ball Touch', 'Successful Ball Touch', 'Take-Ons Overrun',
#        'Touches open play final third', 'Touches open play opp box',
#        'Touches open play opp six yards'],
#       dtype='object', length=104)

# %%
col_eliminar = ["Player ID", "Team Id", 'Opposition id']
df_arquero.drop(col_eliminar, axis = 1, inplace = True)

# %% [markdown]
# Aunque ya hemos disminuido el número de variables, claramente se debe mantener una correlación muy alta entre distintas variables (ejemplo, total pases es la suma de los pases en cada parte de la cancha).

# %%
corr = df_arquero.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_7d5ef_row0_col0, #T_7d5ef_row1_col1, #T_7d5ef_row2_col2, #T_7d5ef_row3_col3, #T_7d5ef_row4_col4, #T_7d5ef_row5_col5, #T_7d5ef_row6_col6, #T_7d5ef_row7_col7, #T_7d5ef_row8_col8, #T_7d5ef_row9_col9, #T_7d5ef_row10_col10, #T_7d5ef_row11_col11, #T_7d5ef_row12_col12, #T_7d5ef_row13_col13, #T_7d5ef_row14_col14, #T_7d5ef_row15_col15, #T_7d5ef_row16_col16, #T_7d5ef_row17_col17, #T_7d5ef_row18_col18, #T_7d5ef_row19_col19, #T_7d5ef_row20_col20, #T_7d5ef_row21_col21, #T_7d5ef_row22_col22, #T_7d5ef_row23_col23, #T_7d5ef_row24_col24, #T_7d5ef_row24_col29, #T_7d5ef_row24_col30, #T_7d5ef_row24_col35, #T_7d5ef_row24_col36, #T_7d5ef_row24_col37, #T_7d5ef_row25_col25, #T_7d5ef_row26_col26, #T_7d5ef_row27_col27, #T_7d5ef_row28_col28, #T_7d5ef_row29_col24, #T_7d5ef_row29_col29, #T_7d5ef_row29_col30, #T_7d5ef_row29_col35, #T_7d5ef_row29_col36, #T_7d5ef_row29_col37, #T_7d5ef_row30_col24, #T_7d5ef_row30_col29, #T_7d5ef_row30_col30, #T_7d5ef_row30_col35, #T_7d5ef_row30_col36, #T_7d5ef_row30_col37, #T_7d5ef_row31_col31, #T_7d5ef_row32_col32, #T_7d5ef_row33_col33, #T_7d5ef_row34_col34, #T_7d5ef_row35_col24, #T_7d5ef_row35_col29, #T_7d5ef_row35_col30, #T_7d5ef_row35_col35, #T_7d5ef_row35_col36, #T_7d5ef_row35_col37, #T_7d5ef_row36_col24, #T_7d5ef_row36_col29, #T_7d5ef_row36_col30, #T_7d5ef_row36_col35, #T_7d5ef_row36_col36, #T_7d5ef_row36_col37, #T_7d5ef_row37_col24, #T_7d5ef_row37_col29, #T_7d5ef_row37_col30, #T_7d5ef_row37_col35, #T_7d5ef_row37_col36, #T_7d5ef_row37_col37, #T_7d5ef_row38_col38, #T_7d5ef_row39_col39, #T_7d5ef_row40_col40, #T_7d5ef_row41_col41, #T_7d5ef_row42_col42, #T_7d5ef_row43_col43, #T_7d5ef_row44_col44, #T_7d5ef_row45_col45, #T_7d5ef_row46_col46, #T_7d5ef_row47_col47, #T_7d5ef_row48_col48, #T_7d5ef_row49_col49, #T_7d5ef_row50_col50, #T_7d5ef_row51_col51, #T_7d5ef_row52_col52, #T_7d5ef_row53_col53, #T_7d5ef_row54_col54, #T_7d5ef_row55_col55, #T_7d5ef_row56_col56, #T_7d5ef_row57_col57, #T_7d5ef_row58_col58, #T_7d5ef_row59_col59, #T_7d5ef_row59_col61, #T_7d5ef_row60_col60, #T_7d5ef_row61_col59, #T_7d5ef_row61_col61, #T_7d5ef_row62_col62, #T_7d5ef_row63_col63, #T_7d5ef_row64_col64, #T_7d5ef_row65_col65, #T_7d5ef_row66_col66, #T_7d5ef_row67_col67, #T_7d5ef_row68_col68, #T_7d5ef_row69_col69, #T_7d5ef_row70_col70, #T_7d5ef_row71_col71, #T_7d5ef_row72_col72, #T_7d5ef_row73_col73, #T_7d5ef_row74_col74, #T_7d5ef_row75_col75, #T_7d5ef_row76_col76, #T_7d5ef_row77_col77, #T_7d5ef_row78_col78, #T_7d5ef_row79_col79, #T_7d5ef_row80_col80, #T_7d5ef_row81_col81, #T_7d5ef_row82_col82, #T_7d5ef_row83_col83, #T_7d5ef_row84_col84, #T_7d5ef_row85_col85, #T_7d5ef_row86_col86, #T_7d5ef_row87_col87, #T_7d5ef_row88_col88, #T_7d5ef_row89_col89, #T_7d5ef_row90_col90, #T_7d5ef_row91_col91, #T_7d5ef_row92_col92, #T_7d5ef_row93_col93, #T_7d5ef_row94_col94, #T_7d5ef_row95_col95, #T_7d5ef_row96_col96, #T_7d5ef_row97_col97, #T_7d5ef_row98_col98, #T_7d5ef_row99_col99, #T_7d5ef_row100_col100 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7d5ef_row0_col1, #T_7d5ef_row5_col8, #T_7d5ef_row19_col9, #T_7d5ef_row46_col42, #T_7d5ef_row70_col85 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_7d5ef_row0_col2, #T_7d5ef_row0_col11, #T_7d5ef_row1_col51, #T_7d5ef_row1_col53, #T_7d5ef_row6_col56, #T_7d5ef_row7_col86, #T_7d5ef_row8_col33, #T_7d5ef_row8_col82, #T_7d5ef_row9_col46, #T_7d5ef_row9_col87, #T_7d5ef_row11_col45, #T_7d5ef_row11_col47, #T_7d5ef_row11_col49, #T_7d5ef_row11_col51, #T_7d5ef_row11_col86, #T_7d5ef_row12_col39, #T_7d5ef_row12_col43, #T_7d5ef_row13_col25, #T_7d5ef_row14_col33, #T_7d5ef_row15_col17, #T_7d5ef_row15_col69, #T_7d5ef_row15_col100, #T_7d5ef_row16_col25, #T_7d5ef_row17_col86, #T_7d5ef_row18_col50, #T_7d5ef_row18_col51, #T_7d5ef_row18_col53, #T_7d5ef_row19_col39, #T_7d5ef_row19_col74, #T_7d5ef_row19_col95, #T_7d5ef_row20_col15, #T_7d5ef_row21_col42, #T_7d5ef_row22_col50, #T_7d5ef_row22_col64, #T_7d5ef_row23_col42, #T_7d5ef_row23_col95, #T_7d5ef_row25_col4, #T_7d5ef_row31_col43, #T_7d5ef_row31_col47, #T_7d5ef_row33_col56, #T_7d5ef_row33_col81, #T_7d5ef_row38_col72, #T_7d5ef_row39_col56, #T_7d5ef_row40_col56, #T_7d5ef_row40_col74, #T_7d5ef_row41_col70, #T_7d5ef_row42_col81, #T_7d5ef_row44_col43, #T_7d5ef_row46_col99, #T_7d5ef_row47_col82, #T_7d5ef_row48_col51, #T_7d5ef_row48_col56, #T_7d5ef_row48_col81, #T_7d5ef_row49_col56, #T_7d5ef_row50_col53, #T_7d5ef_row51_col58, #T_7d5ef_row54_col43, #T_7d5ef_row54_col77, #T_7d5ef_row55_col46, #T_7d5ef_row58_col76, #T_7d5ef_row58_col95, #T_7d5ef_row58_col98, #T_7d5ef_row60_col95, #T_7d5ef_row60_col98, #T_7d5ef_row62_col17, #T_7d5ef_row63_col55, #T_7d5ef_row63_col81, #T_7d5ef_row67_col16, #T_7d5ef_row68_col8, #T_7d5ef_row68_col38, #T_7d5ef_row69_col64, #T_7d5ef_row69_col74, #T_7d5ef_row70_col56, #T_7d5ef_row72_col11, #T_7d5ef_row72_col39, #T_7d5ef_row73_col95, #T_7d5ef_row74_col56, #T_7d5ef_row74_col60, #T_7d5ef_row74_col63, #T_7d5ef_row74_col81, #T_7d5ef_row74_col100, #T_7d5ef_row75_col83, #T_7d5ef_row76_col28, #T_7d5ef_row76_col53, #T_7d5ef_row76_col63, #T_7d5ef_row77_col43, #T_7d5ef_row78_col22, #T_7d5ef_row78_col56, #T_7d5ef_row78_col96, #T_7d5ef_row79_col11, #T_7d5ef_row80_col77, #T_7d5ef_row80_col100, #T_7d5ef_row81_col63, #T_7d5ef_row82_col75, #T_7d5ef_row84_col40, #T_7d5ef_row86_col47, #T_7d5ef_row87_col34, #T_7d5ef_row87_col47, #T_7d5ef_row87_col72, #T_7d5ef_row88_col22, #T_7d5ef_row89_col77, #T_7d5ef_row91_col15, #T_7d5ef_row91_col58, #T_7d5ef_row93_col22, #T_7d5ef_row93_col27, #T_7d5ef_row94_col48, #T_7d5ef_row95_col17, #T_7d5ef_row95_col25, #T_7d5ef_row98_col56, #T_7d5ef_row100_col70 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_7d5ef_row0_col3, #T_7d5ef_row0_col56, #T_7d5ef_row0_col63, #T_7d5ef_row0_col65, #T_7d5ef_row1_col2, #T_7d5ef_row1_col64, #T_7d5ef_row1_col72, #T_7d5ef_row1_col88, #T_7d5ef_row2_col0, #T_7d5ef_row2_col1, #T_7d5ef_row2_col16, #T_7d5ef_row2_col38, #T_7d5ef_row2_col51, #T_7d5ef_row2_col77, #T_7d5ef_row3_col21, #T_7d5ef_row3_col73, #T_7d5ef_row5_col24, #T_7d5ef_row5_col29, #T_7d5ef_row5_col30, #T_7d5ef_row5_col35, #T_7d5ef_row5_col36, #T_7d5ef_row5_col37, #T_7d5ef_row6_col5, #T_7d5ef_row6_col50, #T_7d5ef_row8_col34, #T_7d5ef_row8_col59, #T_7d5ef_row8_col61, #T_7d5ef_row10_col6, #T_7d5ef_row10_col13, #T_7d5ef_row10_col19, #T_7d5ef_row10_col25, #T_7d5ef_row10_col32, #T_7d5ef_row10_col59, #T_7d5ef_row10_col61, #T_7d5ef_row10_col75, #T_7d5ef_row10_col95, #T_7d5ef_row13_col50, #T_7d5ef_row13_col78, #T_7d5ef_row14_col6, #T_7d5ef_row14_col9, #T_7d5ef_row14_col12, #T_7d5ef_row14_col13, #T_7d5ef_row14_col18, #T_7d5ef_row14_col19, #T_7d5ef_row14_col23, #T_7d5ef_row14_col25, #T_7d5ef_row14_col31, #T_7d5ef_row14_col32, #T_7d5ef_row14_col51, #T_7d5ef_row14_col53, #T_7d5ef_row14_col69, #T_7d5ef_row14_col70, #T_7d5ef_row14_col75, #T_7d5ef_row15_col49, #T_7d5ef_row16_col34, #T_7d5ef_row16_col40, #T_7d5ef_row16_col62, #T_7d5ef_row17_col82, #T_7d5ef_row18_col11, #T_7d5ef_row18_col21, #T_7d5ef_row18_col87, #T_7d5ef_row19_col5, #T_7d5ef_row19_col10, #T_7d5ef_row19_col14, #T_7d5ef_row19_col20, #T_7d5ef_row19_col78, #T_7d5ef_row19_col92, #T_7d5ef_row19_col93, #T_7d5ef_row19_col94, #T_7d5ef_row20_col6, #T_7d5ef_row20_col12, #T_7d5ef_row20_col18, #T_7d5ef_row20_col25, #T_7d5ef_row20_col31, #T_7d5ef_row20_col32, #T_7d5ef_row20_col51, #T_7d5ef_row20_col53, #T_7d5ef_row20_col59, #T_7d5ef_row20_col61, #T_7d5ef_row20_col69, #T_7d5ef_row20_col70, #T_7d5ef_row20_col79, #T_7d5ef_row20_col95, #T_7d5ef_row22_col40, #T_7d5ef_row23_col50, #T_7d5ef_row31_col97, #T_7d5ef_row32_col50, #T_7d5ef_row33_col71, #T_7d5ef_row34_col15, #T_7d5ef_row45_col46, #T_7d5ef_row48_col21, #T_7d5ef_row49_col15, #T_7d5ef_row58_col52, #T_7d5ef_row60_col52, #T_7d5ef_row66_col58, #T_7d5ef_row66_col60, #T_7d5ef_row66_col62, #T_7d5ef_row66_col73, #T_7d5ef_row66_col74, #T_7d5ef_row66_col80, #T_7d5ef_row66_col95, #T_7d5ef_row67_col62, #T_7d5ef_row68_col21, #T_7d5ef_row68_col48, #T_7d5ef_row69_col27, #T_7d5ef_row69_col99, #T_7d5ef_row70_col57, #T_7d5ef_row70_col76, #T_7d5ef_row71_col33, #T_7d5ef_row71_col49, #T_7d5ef_row73_col5

# %% [markdown]
# Todavía el número de variables es demasiado alto para hacer análisis uno a uno, por lo tanto, vamos a utilizar svd para reducir dimensiones, haciendo transformaciones a espacios vectoriales más pequeños, buscando mantener el máximo de variabilidad.

# %%
scaler = StandardScaler()
scaler.fit(df_arquero)
df_arquero =scaler.transform(df_arquero)

U, S, VT = svd(df_arquero, full_matrices=False)

idx = range(len(S))
func = [S[0]/((i+1) ** 2) for i in idx ]
plt.plot(idx,func) 
plt.title("Variabilidad explicada")
plt.show()

# %%
var_explained = np.round(S**2/np.sum(S**2), decimals=6)
num_components = 44
sum(var_explained[0:num_components])
# Out:
# 0.903782

# %% [markdown]
# Podemos observar que al retener unicamente 44 componentes del espacio vectorial transformado, mantenemos el $90\%$ de la variabilidad o información, lo cual consideramos que es bastante aceptable

# %%
df_arquero_transformada = df_arquero @ VT[:num_components,:].T
